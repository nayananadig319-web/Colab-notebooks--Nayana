# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#1.Generate Dataset (50 samples)

np.random.seed(42)
n_samples=50

data=pd.DataFrame({
    'Soil_Nitrogen':np.random.normal(70,10,n_samples),
    'Rainfall':np.random.normal(600,100,n_samples),
    'Temperature':np.random.normal(25,5,n_samples),
    'Water_Usage':np.random.normal(400,80,n_samples)
    })

# Create classification label(Healthy=1 , Unhealthy=0)

data['Label']=(
    (data['Soil_Nitrogen']>65) &
    (data['Rainfall']>550) &
    (data['Water_Usage']>350)
).astype(int)

print("Sample Data:\n",data.head())

# 2.Split Features and Labels

x=data.drop('Label',axis=1)
y=data['Label']

# 3. Train_Test Split

x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# 4. Feature Scaling

scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

#5. Build ANN Model
model=Sequential()

# input + Hidden layers

model.add(Dense(8,activation='relu',input_dim = x_train.shape[1]))
model.add(Dense(6,activation='relu'))

# output layer (Binary Classification)
model.add(Dense(1,activation='sigmoid'))

# 6.Compile MOdel

model.compile(
    optimizer ='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# 7. Train Model

history = model.fit(
    x_train,y_train,
    epochs=50,
    batch_size=5,
    verbose=1
)

# 8. Predictions

y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5).astype(int)

#9. Evaluation Metrics

print("\n ----- MOdel Evaluation -----")
accuracy= accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)

print("\n Confusion Matrix:\n",confusion_matrix(y_test, y_pred))
print("\n Classification Report:\n", classification_report(y_test,y_pred))

#10. Plot Training Performance

plt.figure()
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training Accuracy Over Epochs")
plt.legend()
plt.show()
# Out:
# Sample Data:
#     Soil_Nitrogen    Rainfall  Temperature  Water_Usage  Label
# 0      74.967142  632.408397    17.923146   420.039428      1
# 1      68.617357  561.491772    22.896773   427.715857      1
# 2      76.476885  532.307800    23.286427   345.598022      0
# 3      85.230299  661.167629    20.988614   418.580296      1
# 4      67.658466  703.099952    24.193571   423.445798      1
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4250 - loss: 0.7711
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4250 - loss: 0.7527
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4250 - loss: 0.7381
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4250 - loss: 0.7260
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4250 - loss: 0.7118
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4500 - loss: 0.6998
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4750 - loss: 0.6891
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5250 - loss: 0.6792
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5750 - loss: 0.6717
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6250 - loss: 0.6635
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6250 - loss: 0.6550
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6500 - loss: 0.6485
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6500 - loss: 0.6425
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6500 - loss: 0.6359
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7250 - loss: 0.6304
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7250 - loss: 0.6252
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7250 - loss: 0.6198
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7250 - loss: 0.6143
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7250 - loss: 0.6090
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7250 - loss: 0.6046
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.5992
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7750 - loss: 0.5953
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7750 - loss: 0.5901
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7750 - loss: 0.5851
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7750 - loss: 0.5803
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7750 - loss: 0.5752
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7750 - loss: 0.5709
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7750 - loss: 0.5652
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7750 - loss: 0.5593
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7750 - loss: 0.5538
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7750 - loss: 0.5482
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.5423
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.5361
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.5300
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.5239
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8000 - loss: 0.5191
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8000 - loss: 0.5125
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8000 - loss: 0.5064
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8000 - loss: 0.5011
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8250 - loss: 0.4948
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8250 - loss: 0.4897
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8500 - loss: 0.4841
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8500 - loss: 0.4789
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8500 - loss: 0.4738
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8500 - loss: 0.4684
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8500 - loss: 0.4632
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8500 - loss: 0.4586
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8500 - loss: 0.4537
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8500 - loss: 0.4486
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8250 - loss: 0.4440
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#
#  ----- MOdel Evaluation -----
# Accuracy: 0.8
#
#  Confusion Matrix:
#  [[7 0]
#  [2 1]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88         7
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.80        10
#    macro avg       0.89      0.67      0.69        10
# weighted avg       0.84      0.80      0.76        10
