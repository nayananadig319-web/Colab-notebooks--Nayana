# %%
farm_data=[
    [1,"Rice",45],
    [2,"Wheat",30],
    [3,"Maize",60],
]
print(farm_data)
print(farm_data[1])
print(farm_data[2][2])
# Out:
# [[1, 'Rice', 45], [2, 'Wheat', 30], [3, 'Maize', 60]]
# [2, 'Wheat', 30]
# 60

# %%
yield_data=[
    ["Rice",32],
    ["Wheat",28],
    ["Maize",40]
]
for crop in yield_data:
  print(crop[0],"yield:",crop[1],"Kg per hectare")
# Out:
# Rice yield: 32 Kg per hectare
# Wheat yield: 28 Kg per hectare
# Maize yield: 40 Kg per hectare

# %%
crop_plan=[
    ["Kharif",["Rice","Maize"]],
    ["Rabi",["wheat","Gram"]],
    ["Zaid",["Vegetables"]]
]
print(crop_plan[0])
print(crop_plan[0])
print(crop_plan[0][0])
# Out:
# ['Kharif', ['Rice', 'Maize']]
# ['Kharif', ['Rice', 'Maize']]
# Kharif

# %%
expenses=[
    ["Day 1",[100,200,300]],
    ["Day 2",[600,500,200]],
    ["Day 3",[800,100,200]]
]
print(expenses[0])
for day in expenses:
  print(day[1],"total: ",sum(day[1]))
# Out:
# ['Day 1', [100, 200, 300]]
# [100, 200, 300] total:  600
# [600, 500, 200] total:  1300
# [800, 100, 200] total:  1100

# %%
def expenses_made():
  expenses=[]
  number_of_days=int(input("Enter the number of days"))
  for i in range(number_of_days):
    day_name=input(f"Enter the day number: ")

    seed_cost=int(input("Enter the seed cost: "))
    fertilizer_cost=int(input("Enter fertilizer cost: "))
    labour_cost=int(input("Enter the labour cost: "))

    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses

total_expenditure=expenses_made()
print("Daily expenses")
for expenditure in total_expenditure:
  print(expenditure[0],"Day Expenses are",expenditure[1])
# Out:
# Enter the number of days1
# Enter the day number: 1
# Enter the seed cost: 23
# Enter fertilizer cost: 23
# Enter the labour cost: 500
# Daily expenses
# 1 day Expenses are [23, 23, 500]

# %%
thistuple=("apple","banana","cherry","apple","cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %%
thistuple=("apple","banana","cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple=(-1)
print(type(thistuple))
# Out:
# <class 'int'>

# %%
thistuple=(9)
print(type(thistuple))
# Out:
# <class 'int'>

# %%
fruits=("apple","banana","cherry")
print(fruits)

(*green,yellow)=fruits
print(green)
print(yellow)
# Out:
# ('apple', 'banana', 'cherry')
# ['apple', 'banana']
# cherry
