# %%
import pandas as pd
df=pd.DataFrame({
    'A':[10,20,30],
    'B':[1,2,3]
})
print(df[df['A']>15])
# Out:
#     A  B
# 1  20  2
# 2  30  3

# %%
import pandas as pd
df=pd.DataFrame({
    "A":[1,2,3],
    "B":[4,5,6]
})
print(df.shape)
# Out:
# (3, 2)

# %%
import numpy as np
arr=np.arange(8)
arr.reshape(3,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-959/2747304588.py in <cell line: 0>()
#       1 import numpy as np
#       2 arr=np.arange(8)
# ----> 3 arr.reshape(3,3)
#
# ValueError: cannot reshape array of size 8 into shape (3,3)

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-959/4221113189.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot([1,2,3],[4,5])
#       3 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
#    1779             self.add_line(line)
#
# ...

# %%
import numpy as np
a=np.array([1,2])
b=np.array([3,4])
print(np.dot(a,b))
# Out:
# 11

# %%
import pandas as pd
df=pd.DataFrame({"A":[1,2,3]})
print(df.iloc[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-959/2769832346.py in <cell line: 0>()
#       1 import pandas as pd
#       2 df=pd.DataFrame({"A":[1,2,3]})
# ----> 3 print(df.iloc[5])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1750
#    1751             # validate the location
# -> 1752             self._validate_integer(key, axis)
#    1753
# ...

# %%
import pandas as pd
df=pd.DataFrame({"A":[1,2,3]})
print(df["B"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'B'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-959/1844917342.py in <cell line: 0>()
#       1 import pandas as pd
#       2 df=pd.DataFrame({"A":[1,2,3]})
# ...

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
import numpy as np
a=np.array([[1,2],[3,4]])
print(a[0,3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-959/493744186.py in <cell line: 0>()
#       1 import numpy as np
#       2 a=np.array([[1,2],[3,4]])
# ----> 3 print(a[0,3])
#
# IndexError: index 3 is out of bounds for axis 1 with size 2

# %%
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])
