# %%
list1 =["Apple","Banana","Cherry"]
list2 =[1,5,7,9,3]
list3 =[True,False,False]
print(list1)
print(list2)
print(list3)
# Out:
# ['Apple', 'Banana', 'Cherry']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
x=10
y=x
x=5
print(y)
# Out:
# 10

# %%
x=15
if x>10:
  print("A")
if x>5:
  print("B")
# Out:
# A
# B

# %%
x=25
if x>10:
  if x>20:
    print("A")
  else:
    print("B")
else:
  print("C")
# Out:
# A

# %%
i=1
while i<=5:
  i+=2
print (i)
# Out:
# 7

# %%
for i in range(1,6):
  if i%2==0:
    continue
  print(i)
# Out:
# 1
# 3
# 5

# %%
i=0
while i<5:
  i+=1
  if i==3:
    continue
print(i)
# Out:
# 5

# %%
x=[1,2,3]
y=x
z=[1,2,3]
print(x is y,x is z)
# Out:
# True False

# %%
print(5&3)
# Out:
# 1

# %%
print(4<<2)
# Out:
# 16

# %%
print(5^3)
# Out:
# 6
