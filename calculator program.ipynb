# %%
def add(x,y):
  return x+y
def subtract(x,y):
  return x-y
def multiply(x,y):
  return x*y
def divide(x,y):
  if y==0:
    return "ERROR!DIVISION BY ZERO."
  else:
    return x/y
def get_input():
  try:
    x=float(input("Enter the first number: "))
    y=float(input("Enter the second number: "))
    return x,y
  except ValueError: # Corrected typo: Valueerror to ValueError
    print("Invalid input!Please enter valid numbers.")
    return get_input()
def print_menu():
  print("\nSelect the operation: ")
  print("1.Add")
  print("2.Subtract")
  print("3.Multiply")
  print("4.Divide")
  print("5.Exit")
def calculator():
  while True:
    print_menu()
    choice=input("Enter choice(1/2/3/4/5): ") # Moved inside the loop
    if choice=='5':
      print("Exiting the calculator.")
      break # Now correctly inside the while loop

    x,y=get_input()
    if choice=='1':
      print(f"{x}+{y}={add(x,y)}")
    elif choice=='2':
      print(f"{x}-{y}={subtract(x,y)}") # Corrected: was add(x,y)
    elif choice=='3':
      print(f"{x}*{y}={multiply(x,y)}") # Corrected: was add(x,y)
    elif choice=='4':
      print(f"{x}/{y}={divide(x,y)}") # Corrected: was add(x,y)
    else:
      print("Invalid input!Please select a valid operation(1/2/3/4/5): ")
calculator()
print("DONE WITH THE PROGRAM!")
# Out:
# Select the operation:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# Enter choice(1/2/3/4/5): 4.45
# Enter the first number: 4
# Enter the second number: 2
# Invalid input!Please select a valid operation(1/2/3/4/5):
#
# Select the operation:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# Enter choice(1/2/3/4/5): 3.5
# Enter the first number: 3.2
# Enter the second number: 1.9
# Invalid input!Please select a valid operation(1/2/3/4/5):
#
# Select the operation:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# Enter choice(1/2/3/4/5): 4
# Enter the first number: 435
# Enter the second number: 7665
# 435.0/7665.0=0.05675146771037182
#
# Select the operation:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# Enter choice(1/2/3/4/5): 5
# Exiting the calculator.
# DONE WITH THE PROGRAM!

# %%
def add(x,y):
  return x+y
def subtract(x,y):
  return x-y
def multiply(x,y):
  return x*y
def divide(x,y):
  if y==0:
    return "error!division by zero"
  else:
    return x/y
def get_input():
  try:
    x=float(input("enter the first number:"))
    y=float(input("enter the second number"))
    return x,y
  except valueError:
    print("invalid input!please enter valid number.")
    return get_input()
def print_menu():
    print("\n select operation:")
    print("1.Add")
    print("2.subtract")
    print("3.multiply")
    print("4.divide")
    print("5.exit")
def calculator():
  while True:
    print_menu()
choice=input("Enter choice(1/2/3/4/5):")
if choice=='5':
  print("Exiting the calculator")
  break
x,y=get_input()
if choice=='1':
  print(f"{x}+{y}={add(x,y)}")
elif choice=='2':
  print(f"{x}-{y}={subtract(x,y)}")
elif choice=='3':
  print(f"{x}*{y}={multiply(x,y)}")
elif choice=='5':
  print(f"{x}/{y}={divide(x,y)}")
else:
  print("invalid input!please select a valid operation(1/2/3/4/5).")
  calculator()
  print("done with program")
