# %%
# ====crop monitoring report====

farmer_name=input("enter farmer name:")
crop_name=input("enter crop name:")
total_land_area=float(input("enter total land area(acres):"))
water_required=float(input("enter water required per acre(liters):"))
available_water=float(input("enter available water(liters):"))
fertilizer_applied=bool(input("is fertilizer applied(True/False):"))
sensor_id=int(input("enter sensor id:"))
authorized_sensor_id=int(input("enter authorized sensor id:"))

total_water_required=land_area*water_required_per_acre
water_balance=available_water-total_water_required

available_water-=500
land_area+=1

irigation_feasible=(available_water>=total_water_required) and fertilizer_applied

approved_crops={"wheat","rice","maize"}
crop_eligible=crop_name in approved_crops

sensor_authenticated=sensor_id == authorized_sensor_id

bitwise_AND=sensor_id & authorized_sensor_id
bitwise_OR=sensor_id | authorized_sensor_id
bitwise_XOR=sensor_id^authorized_sensor_id

print("\n---smart crop monitoring report---")
print("farmer name:",farmer_name)
print("crop_name:",crop_name)
print("total_land_area:",land_area,"acres")
print("water_required:",total_water_required,"liters")
print("water_balance:",water_balance,"liters")
print("available_water:",available_water,"liters")
print("irigation_feasible:",irigation_feasible)
print("fertilizer_applied:",fertilizer_applied)
print("crop_eligible:",crop_eligible)
print("sensor authenticated:",sensor_authenticated)
print("bitwise AND:",bitwise_AND)
print("bitwise OR:",bitwise_OR)
print("bitwise XOR:",bitwise_XOR)
print("\n====end of report====")
# Out:
# enter farmer name:geetha
# enter crop name:maize
# enter total land area(acres):5
# enter water required per acre(liters):500000
# enter available water(liters):400000
# is fertilizer applied(True/False):false
# enter sensor id:678
# enter authorized sensor id:678
#
# ---smart crop monitoring report---
# farmer name: geetha
# crop_name: maize
# total_land_area: 10.0 acres
# water_required: 45000.0 liters
# water_balance: 355000.0 liters
# available_water: 399500.0 liters
# irigation_feasible: True
# fertilizer_applied: True
# crop_eligible: True
# sensor authenticated: True
# bitwise AND: 678
# bitwise OR: 678
# bitwise XOR: 0
#
# ====end of report====
