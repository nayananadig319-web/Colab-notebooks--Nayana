# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2022
}
print(thisdict)
# Out:
# {'crop': 'rice', 'variety': 'IR-64', 'year': 2022}

# %%
thisdict={
    "crop":"cotton",
    "organic":"true",
    "year":2024,
    "irrigation_methods":["drip","sprinkler","flood"]
}
print(thisdict)
# Out:
# {'crop': 'cotton', 'organic': 'true', 'year': 2024, 'irrigation_methods': ['drip', 'sprinkler', 'flood']}

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2022
}
print(type(thisdict))
# Out:
# <class 'dict'>

# %%
thisdict=dict(
    farmer_name="ramesh",
    age=45,
    village="mandya"
)
print(thisdict)
# Out:
# {'farmer_name': 'ramesh', 'age': 45, 'village': 'mandya'}

# %%
x=thisdict["variety"]
print(x)
# Out:
# IR-64

# %%
x=thisdict.get("variety")
print(x)
# Out:
# IR-64

# %%
x=thisdict.keys()
print(x)
# Out:
# dict_keys(['crop', 'variety', 'year'])

# %%
farm={
    "crop":"rice",
    "variety":"IR-64",
    "year":2022
}
}
x=farm.keys()
print(x)
farm["season"]="kharif"
print(x)
# Out:
# dict_keys(['crop', 'variety', 'year'])
# dict_keys(['crop', 'variety', 'year', 'season'])

# %%
x=thisdict.values()
print(x)
# Out:
# dict_values(['rice', 'IR-64', 2022])

# %%
x=farm.values()
print(x)
farm["year"]=2024
print(x)
# Out:
# dict_values(['rice', 'IR-64', 2022, 'kharif'])
# dict_values(['rice', 'IR-64', 2024, 'kharif'])

# %%
#x=thisdict.items()
#print(x)
tuple2=tuple(thisdict.items())
print(tuple2)
print(x)
x_keys=tuple(thisdict.keys())
x_values=list(thisdict.values())
print(x_keys)
print(x_values)
pairs=zip(x_keys,x_values)
print(tuple(pairs))
# Out:
# (('crop', 'rice'), ('variety', 'IR-64'), ('year', 2022))
# dict_items([('crop', 'rice'), ('variety', 'IR-64'), ('year', 2022)])
# ('crop', 'variety', 'year')
# ['rice', 'IR-64', 2022]
# (('crop', 'rice'), ('variety', 'IR-64'), ('year', 2022))

# %%
thsidict={
    "crop":"rice",
    "variety":"IR-64",
    "year":2022
}
if "crop"in thisdict:
  print("True,'crop' is one of the keys in the thisdict dictionary")
# Out:
# True,'crop' is one of the keys in the thisdict dictionary

# %%
student={
    "name":"Anitha",
    "roll_no":101,
    "branch":"CSE",
    "marks":88
}
print("original dictionary:",student)
# Out:
# original dictionary: {'name': 'Anitha', 'roll_no': 101, 'branch': 'CSE', 'marks': 88}

# %%
student = {
    "name": "Raj",
    "marks": {"math": 90, "cs": 95}
}
print(student)
# Out:
# {'name': 'Raj', 'marks': {'math': 90, 'cs': 95}}
