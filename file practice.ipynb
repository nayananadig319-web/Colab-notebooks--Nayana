# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-61241d66-0795-4a52-9def-a663fef077d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61241d66-0795-4a52-9def-a663fef077d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("Persimmons1.txt", "r") as file:
    for record in file:
        record = record.strip()
        if "pear" in record:
            print(record)
# Out:
# Although pear is good, buy its costly

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9ee9ef3c-dc9e-4bf9-ac46-7897ed79802e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ee9ef3c-dc9e-4bf9-ac46-7897ed79802e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file = open("crop1.txt", "r")
print(file.read())
file.close()
# Out:
# CRP_RICE_2026
# CRP_WHEAT_2025
# CRP_RICE_2027
# CRP_MAIZE_2024
# CRP_WHEAT_2023

# %%
file = open("crop_data.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# CRP_RICE_2026,Rice,Kharif,High
# CRP_WHEAT_2025,Wheat,Rabi,Medium
