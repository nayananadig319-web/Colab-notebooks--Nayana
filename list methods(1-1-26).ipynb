# %%
#Negative indexing
#Negative indexing means start from the end
#-1 refers to last  item,-2 refers to the second last item
thislist=["apple","banana","cherry"]
print(thislist[1])
# Out:
# banana

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[1:9])
# Out:
# ['banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[4: ])
# Out:
# ['kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[-7:-4])
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[ :4])
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist=["apple","banana","cherry"]
thislist[-2]="blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
thislist=["apple","banana","cherry"]
thislist[2:1]=["blackcurrant","watermelon"]
print(thislist)
# Out:
# ['apple', 'banana', 'blackcurrant', 'watermelon', 'cherry']

# %%
thislist=["apple","banana","cherry"]
thislist[3:]=["watermelon"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'watermelon']

# %%
thislist=["apple","banana","cherry"]
thislist.insert(-1,"watermelon")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %%
thislist=["apple","banana","cherry"]
tropical=["mango","pineapple","papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
thislist=["apple","banana","cherry"]
tropical=["mango","pineapple","papaya"]
a=10
b=20
c=a+b
thislist=thislist+tropical
print(thislist)
print(c)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']
# 30

# %%
thislist=["Apple","banana","banana","cherry"]
thislist.remove("banana")
thislist.remove("banana")
print(thislist)
# Out:
# ['Apple', 'cherry']

# %%
thislist=["Apple","banana","cherry"]
thislist.pop(2)
print(thislist)
# Out:
# ['Apple', 'banana']

# %%
thislist=["UASB","UASD","TNAU","PJTSAU"]
thislist.pop(-4)
print(thislist)
# Out:
# ['UASD', 'TNAU', 'PJTSAU']

# %%
thislist=["Apple","banana","cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
#List Length

thislist = ["apple", "banana", "cherry"]
print(len(thislist))
# Out:
# 3

# %%
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]

print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']
