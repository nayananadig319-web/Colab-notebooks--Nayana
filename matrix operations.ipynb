# %%
import numpy as np
A=np.array([[1,2],[3,4]])
B=np.array([[5,6],[7,8]])
A @ B
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
import numpy as np
A=np.array([[1,2],[3,4]])
B=np.array([[5,6],[7,8]])
A*B
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %%
import numpy as np
matrix=np.array([[1,2],[3,4]])
transposed=matrix.T

# %%
matrix=[
    [1,2,3],
    [4,5,6]
]
transpose=list(zip(*matrix))
print("transpose matrix")
for row in transpose:
  print(list(row))
# Out:
# transpose matrix
# [1, 4]
# [2, 5]
# [3, 6]

# %%
import numpy as np
A=np.array([[1,2],[3,4]])
B=np.array([[5,6],[7,8]])
A+B
# Out:
# array([[ 6,  8],
#        [10, 12]])

# %%
import numpy as np
A=np.array([[1,2],[3,4]])
B=np.array([[5,6],[7,8]])
A-B
# Out:
# array([[-4, -4],
#        [-4, -4]])
