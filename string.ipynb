# %%
crop="Rice"
soil_type="Black soil"
print(crop)
print(soil_type)
print(len(crop))
print(len(soil_type))
# Out:
# Rice
# Black soil
# 4
# 10

# %%
crop_name="Groundnut"
print(crop_name[0])
print(crop_name[-3])
print(crop_name[ :6])
print(crop_name[4: ])
# Out:
# G
# n
# Ground
# ndnut

# %%
print("rice".upper())
print("WHEAT".lower())
print("green gram".title())
print("cotton crop".capitalize())
# Out:
# RICE
# wheat
# Green Gram
# Cotton crop

# %%
raw_crop="Rice"
print(raw_crop.strip())
print("***  wheat  ".lstrip("* "))
print("  Maize###".strip(" #"))
# Out:
# Rice
# wheat
# Maize

# %%
text="Organic Rice and Rice cultivtion"
print(text.find("Rice"))
print(text.count("Rice"))
print("Rice" in text)
# Out:
# 8
# 2
# True

# %%
print("rice".isalpha())
print("2026".isdigit())
print("plot12".isalnum())
print("  ".isspace())
# Out:
# True
# True
# True
# True

# %%
codes=[
    "CRP_RICE_2026",
    "CRP_WHEAT_2025",
    "FRT_MANGO_2026",
    "CRP_MAIZE_2024"
]
clean_codes=[]
for code in codes:
  if code.startswith("CRP_"):
    clean_codes.append(code[4:])
print(clean_codes)
# Out:
# ['RICE_2026', 'WHEAT_2025', 'MAIZE_2024']

# %%
for crop_code in codes:
  if crop_code.startswith("FRT_"):
    code,crop,year=crop_code.split("_")
    print(code,crop,year)
# Out:
# FRT MANGO 2026

# %%
raw_record="  Rice,1200,Black soil**"
crop,yield_kg,soil=clean_record1.split(",")
crop=crop.title()

print(f"crop:{crop}")
print(f"yield:{yield_kg} kg")
print(f"soil:{soil}")
# Out:
# crop:Rice
# yield:1200 kg
# soil:Black soil
